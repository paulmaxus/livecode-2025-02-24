# %%
import pandas as pd

# %%
name = "max"

# %%
name
# Out:
# 'max'

# %%
data = pd.read_csv("../data/gapminder_gdp_europe.csv", index_col="country")

# %%
data.head(3)
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Albania     1601.056136     1942.284244     2312.888958     2760.196931
# Austria     6137.076492     8842.598030    10750.721110    12834.602400
# Belgium     8343.105127     9714.960623    10991.206760    13149.041190
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Albania     3313.422188      3533.00391     3630.880722     3738.932735
# Austria    16661.625600     19749.42230    21597.083620    23687.826070
# Belgium    16672.143560     19117.97448    20979.845890    22525.563080
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Albania     2497.437901     3193.054604     4604.211737     5937.029526
# Austria    27042.018680    29095.920660    32417.607690    36126.492700
# Belgium    25575.570690    27561.196630    30485.883750    33692.605080

# %%
mask = data > 10000

# %%
data[mask].head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                            NaN             NaN             NaN
# Austria                            NaN             NaN     10750.72111
# Belgium                            NaN             NaN     10991.20676
# Bosnia and Herzegovina             NaN             NaN             NaN
# Bulgaria                           NaN             NaN             NaN
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                            NaN             NaN             NaN
# Austria                    12834.60240     16661.62560     19749.42230
# Belgium                    13149.04119     16672.14356     19117.97448
# Bosnia and Herzegovina             NaN             NaN             NaN
# Bulgaria                           NaN             NaN             NaN
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %% [markdown]
# ## Summary statistics based on groups
#
# - mask
# - groups
# - summary functions / aggregation functions

# %%
data.head(3)
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Albania     1601.056136     1942.284244     2312.888958     2760.196931
# Austria     6137.076492     8842.598030    10750.721110    12834.602400
# Belgium     8343.105127     9714.960623    10991.206760    13149.041190
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Albania     3313.422188      3533.00391     3630.880722     3738.932735
# Austria    16661.625600     19749.42230    21597.083620    23687.826070
# Belgium    16672.143560     19117.97448    20979.845890    22525.563080
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Albania     2497.437901     3193.054604     4604.211737     5937.029526
# Austria    27042.018680    29095.920660    32417.607690    36126.492700
# Belgium    25575.570690    27561.196630    30485.883750    33692.605080

# %%
data.mean(axis=0) # default 0: rows, 1: columns
# Out:
# gdpPercap_1952     5661.057435
# gdpPercap_1957     6963.012816
# gdpPercap_1962     8365.486814
# gdpPercap_1967    10143.823757
# gdpPercap_1972    12479.575246
# gdpPercap_1977    14283.979110
# gdpPercap_1982    15617.896551
# gdpPercap_1987    17214.310727
# gdpPercap_1992    17061.568084
# gdpPercap_1997    19076.781802
# gdpPercap_2002    21711.732422
# gdpPercap_2007    25054.481636
# dtype: float64

# %%
mask_higher_avg = data > data.mean()

# %%
mask_higher_avg.head(3)
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Albania           False           False           False           False
# Austria            True            True            True            True
# Belgium            True            True            True            True
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Albania           False           False           False           False
# Austria            True            True            True            True
# Belgium            True            True            True            True
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Albania           False           False           False           False
# Austria            True            True            True            True
# Belgium            True            True            True            True

# %%
data.iloc[0,0]
# Out:
# np.float64(1601.056136)

# %%
data[mask_higher_avg].head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                            NaN             NaN             NaN
# Austria                    6137.076492     8842.598030     10750.72111
# Belgium                    8343.105127     9714.960623     10991.20676
# Bosnia and Herzegovina             NaN             NaN             NaN
# Bulgaria                           NaN             NaN             NaN
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                            NaN             NaN             NaN
# Austria                    12834.60240     16661.62560     19749.42230
# Belgium                    13149.04119     16672.14356     19117.97448
# Bosnia and Herzegovina             NaN             NaN             NaN
# Bulgaria                           NaN             NaN             NaN
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %%
wealth_score = mask_higher_avg.mean()

# %% [markdown]
# ## Boolean -> Numerical

# %%
type(False)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %%
type(4 > 5)
# Out:
# bool

# %%
int(False)
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
mask_higher_avg.head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                          False           False           False
# Austria                           True            True            True
# Belgium                           True            True            True
# Bosnia and Herzegovina           False           False           False
# Bulgaria                         False           False           False
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                          False           False           False
# Austria                           True            True            True
# Belgium                           True            True            True
# Bosnia and Herzegovina           False           False           False
# Bulgaria                         False           False           False
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %%
wealth_score = mask_higher_avg.mean(axis=1)

# %%
wealth_score.head(10)
# Out:
# country
# Albania                   0.0
# Austria                   1.0
# Belgium                   1.0
# Bosnia and Herzegovina    0.0
# Bulgaria                  0.0
# Croatia                   0.0
# Czech Republic            0.5
# Denmark                   1.0
# Finland                   1.0
# France                    1.0
# dtype: float64

# %% [markdown]
# ## Grouping

# %%
data.groupby(wealth_score).mean()
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# 0.000000     3076.404517     3842.576566     4737.505453     5943.737399
# 0.333333     4197.511720     5235.614200     6436.233830     8391.916917
# 0.500000     5903.772203     7252.500075     9190.224735    10710.923100
# 1.000000     8693.106463    10611.000728    12499.096183    14833.362503
#
#           gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# 0.000000     7380.778908     8704.946536     9462.814042     9970.799951
# 0.333333    11319.459994    13465.114187    14919.908505    16109.228240
# 0.500000    12688.863690    14528.072685    15957.356025    17758.839110
# 1.000000    17930.195262    20095.284394    21949.065163    24735.427601
#
#           gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# 0.000000     7698.337271     8647.744800     9882.577489    12464.779827
# 0.333333    16979.523305    20219.012895    25521.698802    30700.932380
# ...

# %%
data.groupby(wealth_score).aggregate()
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# 0.000000              12              12              12              12
# 0.333333               4               4               4               4
# 0.500000               2               2               2               2
# 1.000000              12              12              12              12
#
#           gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# 0.000000              12              12              12              12
# 0.333333               4               4               4               4
# 0.500000               2               2               2               2
# 1.000000              12              12              12              12
#
#           gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# 0.000000              12              12              12              12
# 0.333333               4               4               4               4
# ...

# %%
data["religion"] = "text"

# %%
data.head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                    2760.196931     3313.422188     3533.003910
# Austria                   12834.602400    16661.625600    19749.422300
# Belgium                   13149.041190    16672.143560    19117.974480
# Bosnia and Herzegovina     2172.352423     2860.169750     3528.481305
# Bulgaria                   5577.002800     6597.494398     7612.240438
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %%
data.groupby("fixed").mean()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# fixed
# text      5661.057435     6963.012816     8365.486814    10143.823757
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# fixed
# text     12479.575246     14283.97911    15617.896551    17214.310727
#
#        gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# fixed
# text     17061.568084    19076.781802    21711.732422    25054.481636

# %% [markdown]
# ## Create category labels

# %%
data.iloc[0:3,-1] = "string"
#data["fixed"].iloc[0:3]

# %%
data["fixed"].head()
# Out:
# country
# Albania                   string
# Austria                   string
# Belgium                   string
# Bosnia and Herzegovina      text
# Bulgaria                    text
# Name: fixed, dtype: object

# %%
data.groupby("fixed").mean()
# Out:
#         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# fixed
# string     5360.412585     6833.280966     8018.272276     9581.280174
# text       5694.462418     6977.427466     8404.066207    10206.328599
#
#         gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# fixed
# string    12215.730449    14133.466897    15402.603411    16650.773962
# text      12508.891335    14300.702689    15641.818011    17276.925923
#
#         gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# fixed
# string    18371.675757    19950.057298    22502.567726    25252.042435
# text      16916.000565    18979.751191    21623.861833    25032.530436

# %%
data.head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                    2760.196931     3313.422188     3533.003910
# Austria                   12834.602400    16661.625600    19749.422300
# Belgium                   13149.041190    16672.143560    19117.974480
# Bosnia and Herzegovina     2172.352423     2860.169750     3528.481305
# Bulgaria                   5577.002800     6597.494398     7612.240438
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...
